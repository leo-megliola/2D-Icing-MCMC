# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from tqdm.notebook import tqdm
import yaml

from utils import *

# %%
#getting the parameters from the yaml file
with open("config.yaml", 'r') as stream:
    try:
        config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)
print(config)
STEPS = config['STEPS']
N = config['N']
J = config['J']
KB = config['KB']
T = config['T']
BURNIN = config['BURNIN']
lol = random_spins(N)
# Out:
# {'STEPS': 1000000, 'N': 30, 'J': 1, 'KB': 1, 'T': 2, 'BURNIN': 100000}

# %%
m_valuesUP, lattice_spins, steps = spins(steps=STEPS, random=False)
plot_lattice(lattice_spins, savefig="latticeplot.png")
plot_m(m_valuesUP, burn_in = BURNIN, savefig="mplot.png")
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# magnetization mean = 0.963105560493827
# magnetization std = 0.009264658214116303
