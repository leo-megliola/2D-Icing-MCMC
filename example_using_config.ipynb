# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from tqdm import tqdm
import yaml

from utils import *

# %%
#getting the parameters from the yaml file
with open("config.yaml", 'r') as stream:
    try:
        config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)
print(config)
STEPS = config['STEPS']
N = config['N']
J = config['J']
KB = config['KB']
T = config['T']
BURNIN = config['BURNIN']
B = config['B']
lol = random_spins(N)
# Out:
# {'STEPS': 1000000, 'N': 30, 'J': 1, 'KB': 1, 'T': 2, 'BURNIN': 100000, 'B': 1, 'T_C': 2.269}

# %%
# m_valuesUP, lattice_spins, steps = spins(steps=STEPS, random=False)
# plot_lattice(lattice_spins, savefig="latticeplot.png")
# plot_m(m_valuesUP, burn_in = BURNIN, savefig="mplot.png")

# %%
B=100
m_valuesUP, lattice_spins, steps = spins(steps=STEPS, random=False, B=B)
plot_lattice(lattice_spins, savefig="latticeplot.png")
plot_m(m_valuesUP, burn_in = BURNIN, savefig="mplot.png")
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# magnetization mean = -1.0
# magnetization std = 0.0

# %%
B=1
m_valuesUP, lattice_spins, steps = spins(steps=STEPS, random=False, B=B)
plot_lattice(lattice_spins, savefig="latticeplot.png")
plot_m(m_valuesUP, burn_in = BURNIN, savefig="mplot.png")
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# magnetization mean = -0.9701763333333333
# magnetization std = 0.010120099984799163

# %%
B=-100
m_valuesUP, lattice_spins, steps = spins(steps=STEPS, random=False, B=B)
plot_lattice(lattice_spins, savefig="latticeplot.png")
plot_m(m_valuesUP, burn_in = BURNIN, savefig="mplot.png")
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# magnetization mean = 1.0
# magnetization std = 0.0

# %%
B=-100
m_valuesUP, lattice_spins, steps = spins(steps=STEPS, random=True, B=B)
plot_lattice(lattice_spins, savefig="latticeplot.png")
plot_m(m_valuesUP, burn_in = BURNIN, savefig="mplot.png")
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# magnetization mean = 1.0
# magnetization std = 0.0
