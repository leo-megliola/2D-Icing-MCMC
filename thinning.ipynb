# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from tqdm.notebook import tqdm
import yaml

from utils import *

# %%
M,L,_ = spins_py(steps=10_000_000, random=True, temp=2.5, size=100, J=1, KB=1, B=0, display=True)
# Out:
#   0%|          | 0/10000000 [00:00<?, ?it/s]

# %%
M.shape
# Out:
# (10000000,)

# %%
M[::2].shape
# Out:
# (5000000,)

# %%
Mb = M[350_000:]
thinning = [x+1 for x in range(50)]
plt.scatter(thinning, [np.std(M[::t]) for t in thinning])

# %%
Mb = M[350_000:]
thinning = [x+1 for x in range(50)]
plt.scatter(thinning, [np.mean(M[::t]) for t in thinning])
